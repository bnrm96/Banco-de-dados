# %% [markdown]
# # **Dados Da Empresa**
#
# Nesta parte do processamento, iremos utilizar a primeira forma normal para a visualização de todos os dados da empresa/ gestora. Nesta etapa, é importante ressaltar que todos os dados de clientes e funcionários estão contidos em uma longa tabela.

# %%
# Importando Bibliotecas padrão
import pandas as pd

# %% [markdown]
# # Visualizando os Dados:

# %%
DFempresa = pd.read_csv('DadosSistema/DadosDaEmpresa.csv')
display(DFempresa)
# Out:
#    Matricula                  Nome   Data/Nasc   Sexo          CPF  \
# 0          1          João Santino  1998-01-03   True    123456789
# 1          2       Maria Vitctoria  2000-01-04  False    123456789
# 2          3             Léo Sales  2001-02-10   True    123456789
# 3          4        Madre Teresino  2002-01-14  False    123456789
# 4          5       Thiago Ferreira  1990-08-21   True    123456789
# 5          6       Douglas Costela  1999-04-16   True    123456789
# 6          7  Snnider Scharwttiger  2008-01-11   True    123456789
# 7      12345                 André  2002-02-20   True  66485800461
# 8      12345               Kleyton  1998-06-10   True  38593800438
#
#                             Endereço   Telefone  \
# 0                              Rua 1   23456789
# 1                              Rua 2   22222223
# 2                              Rua 3   33333334
# 3                        Rua Denório   44444449
# 4                       Rua Flincher   66666666
# ...
